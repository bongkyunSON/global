# %%
arr = [0, 1, 2, 4, 3]
queries = [[0, 4, 2],[0, 3, 2],[0, 2, 2]]
# s, e, k = queries

# s_que = arr[s[0]:s[1]+1]
# e_que = arr[e[0]:e[1]+1]
# k_que = arr[k[0]:k[1]+1]



def solution(arr, queries):
    before = []
    answer = []
    for s, e, k in queries:
        for i in arr[s:e+1]:
            print(i)
            # if i > k:
            #     answer.append(i)
            #     print(i)

        # answer.append(min(before))
    
    return answer

solution(arr, queries)
# Out:
# 4
# 3
# 4
# [4, 3, 4]

# %%
arr = [0, 1, 2, 4, 3]
queries = [[0, 4, 2],[0, 3, 2],[0, 2, 2]]

answer = []

for s, e, k in queries:
    before = []
    for i in arr[s:e+1]:
        if i > k:
            before.append(i)
    if len(before) >= 1:
        answer.append(min(before))
    else:
        answer.append(-1)

answer
# Out:
# [3, 4, -1]

# %%
arr = [0, 1, 2, 4, 3]
queries = [[0, 4, 1],[0, 3, 2],[0, 3, 3]]


def solution(arr, queries):
    
    for s, e, k in queries:
        # answer = []
        for i, v in enumerate(arr[s:e+1]):
            if s<= i and i <=e:
                if i % k == 0:
                    arr[i] += 1
        

    return arr




solution(arr, queries)
# Out:
# [3, 2, 4, 6, 4]

# %%
arr = [0, 1, 2, 4, 3]
answer = []
for i in arr[0:5]:
    if i % 3 == 0:
        print(i)
        answer.append(i+1)

answer
# Out:
# 0
# 3
# [1, 4]

# %%
# Out:
# 0
